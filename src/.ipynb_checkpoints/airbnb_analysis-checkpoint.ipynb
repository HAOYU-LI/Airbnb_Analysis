# %% [markdown]
# # Airbnb data insight for Boston and Seattle area

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# Since 2008, guests and hosts have used Airbnb to travel in a more unique, personalized way. As part of the Airbnb Inside initiative, this dataset describes the listing activity of homestays in Seattle, WA.

# %% [markdown]
# Airbnb is currently a very popular platform for both guests and hosts to enjoy their customized travellings. There are many interesting things we can explore using the data from Airbnb insight. Let's get started by using the data of Boston and Seattle cities.

# %% [markdown]
# Three interesting questions come to my mind when looking into the data:
#
# 1. Is there any difference in price between Boston and Seattle area?
# 2. Can we predict price in Boston and Seattle Airbnb using this dataset?
# 3. What's the top important features when predicting the price in two cities?

# %% [markdown]
# ## Load the data first:

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import mplleaflet
from tqdm import tqdm
from xgboost import plot_importance
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
boston_listings = pd.read_csv('../data/boston/listings.csv')
seattle_listings = pd.read_csv('../data/seattle/listings.csv')

# %%
boston_listings.head(2)
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
#
#   last_scraped                               name  \
# 0   2016-09-07         Sunny Bungalow in the City
# 1   2016-09-07  Charming room in pet friendly apt
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
#
#                                                space  \
# 0  The house has an open and cozy feel at the sam...
# 1  Small but cozy and quite room with a full size...
#
#                                          description experiences_offered  \
# 0  Cozy, sunny, family home.  Master bedroom high...                none
# 1  Charming and quiet room in a second floor 1910...                none
#
#                                neighborhood_overview        ...          \
# 0  Roslindale is quiet, convenient and friendly. ...        ...
# 1  The room is in Roslindale, a diverse and prima...        ...
#
#   review_scores_value requires_license license jurisdiction_names  \
# 0                 NaN                f     NaN                NaN
# 1                 9.0                f     NaN                NaN
#
#   instant_bookable cancellation_policy require_guest_profile_picture  \
# 0                f            moderate                             f
# 1                t            moderate                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              1
# 1                                f                              1
#
#    reviews_per_month
# 0                NaN
# 1                1.3
#
# [2 rows x 95 columns]

# %%
seattle_listings.head(2)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  241032  https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1  953595  https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
#
#                                  name  \
# 0        Stylish Queen Anne Apartment
# 1  Bright & Airy Queen Anne Apartment
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
#
#                                neighborhood_overview        ...         \
# 0                                                NaN        ...
# 1  Queen Anne is a wonderful, truly functional vi...        ...
#
#   review_scores_value requires_license license jurisdiction_names  \
# 0                10.0                f     NaN         WASHINGTON
# 1                10.0                f     NaN         WASHINGTON
#
#   instant_bookable cancellation_policy  require_guest_profile_picture  \
# 0                f            moderate                              f
# 1                f              strict                              t
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
# 1                                t                              6
#
#   reviews_per_month
# 0              4.07
# 1              1.48
#
# [2 rows x 92 columns]

# %%
boston_listings.shape
# Out:
# (3585, 95)

# %%
seattle_listings.shape
# Out:
# (3818, 92)

# %%
boston_listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %%
seattle_listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# ## Visualize airbnb location in Boston and Seattle area

# %% [markdown]
# Dataset from both Boston and Seattle contains geographical information. Let's draw their geospatial distribution in map to take a look.

# %%
boston_samples = boston_listings.sample(100)
plt.scatter(boston_samples['longitude'], boston_samples['latitude'])
mplleaflet.display()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="240"></iframe>

# %%
seattle_samples = seattle_listings.sample(100)
plt.scatter(seattle_samples['longitude'], seattle_samples['latitude'])
mplleaflet.display()
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="240"></iframe>

# %% [markdown]
# As our expectation, most rents locate at downtown area, where travellers can find more fun :)). Let's try to solve the three questions above then.

# %% [markdown]
# ## Is there any difference in price and review?

# %%
boston_prices = pd.read_csv('../data/boston/calendar.csv').dropna(how = 'any', axis = 0)
seattle_prices = pd.read_csv('../data/seattle/calendar.csv').dropna(how = 'any', axis = 0)

# %%
seattle_prices.head()
# Out:
#     listing_id        date available   price
# 0       241032  2016-01-04         t  $85.00
# 1       241032  2016-01-05         t  $85.00
# 9       241032  2016-01-13         t  $85.00
# 10      241032  2016-01-14         t  $85.00
# 14      241032  2016-01-18         t  $85.00

# %%
seattle_prices
# Out:
#                id        date available  price
# 0          241032  2016-01-04         t   85.0
# 1          241032  2016-01-05         t   85.0
# 9          241032  2016-01-13         t   85.0
# 10         241032  2016-01-14         t   85.0
# 14         241032  2016-01-18         t   85.0
# 15         241032  2016-01-19         t   85.0
# 16         241032  2016-01-20         t   85.0
# 20         241032  2016-01-24         t   85.0
# 21         241032  2016-01-25         t   85.0
# 22         241032  2016-01-26         t   85.0
# 23         241032  2016-01-27         t   85.0
# 24         241032  2016-01-28         t   85.0
# 28         241032  2016-02-01         t   85.0
# 29         241032  2016-02-02         t   85.0
# 30         241032  2016-02-03         t   85.0
# 31         241032  2016-02-04         t   85.0
# 32         241032  2016-02-05         t   85.0
# 33         241032  2016-02-06         t   85.0
# 34         241032  2016-02-07         t   85.0
# 35         241032  2016-02-08         t   85.0
# 36         241032  2016-02-09         t   85.0
# 37         241032  2016-02-10         t   85.0
# 41         241032  2016-02-14         t   85.0
# 42         241032  2016-02-15         t   85.0
# 43         241032  2016-02-16         t   85.0
# 44         241032  2016-02-17         t   85.0
# 45         241032  2016-02-18         t   85.0
# 46         241032  2016-02-19         t   85.0
# 47         241032  2016-02-20         t   85.0
# 48         241032  2016-02-21         t   85.0
# ...           ...         ...       ...    ...
# 1392996   9604740  2016-06-08         t   99.0
# 1392997   9604740  2016-06-09         t   99.0
# 1392998   9604740  2016-06-10         t   99.0
# 1392999   9604740  2016-06-11         t   99.0
# 1393000   9604740  2016-06-12         t   99.0
# 1393001   9604740  2016-06-13         t   99.0
# 1393002   9604740  2016-06-14         t   99.0
# 1393003   9604740  2016-06-15         t   99.0
# 1393004   9604740  2016-06-16         t   99.0
# 1393005   9604740  2016-06-17         t   99.0
# 1393006   9604740  2016-06-18         t   99.0
# 1393007   9604740  2016-06-19         t   99.0
# 1393008   9604740  2016-06-20         t   99.0
# 1393009   9604740  2016-06-21         t   99.0
# 1393010   9604740  2016-06-22         t   99.0
# 1393011   9604740  2016-06-23         t   99.0
# 1393012   9604740  2016-06-24         t   99.0
# 1393013   9604740  2016-06-25         t   99.0
# 1393014   9604740  2016-06-26         t   99.0
# 1393015   9604740  2016-06-27         t   99.0
# 1393016   9604740  2016-06-28         t   99.0
# 1393017   9604740  2016-06-29         t   99.0
# 1393018   9604740  2016-06-30         t   99.0
# 1393205  10208623  2016-01-04         t   87.0
# 1393206  10208623  2016-01-05         t   87.0
# 1393207  10208623  2016-01-06         t   87.0
# 1393208  10208623  2016-01-07         t   87.0
# 1393211  10208623  2016-01-10         t   87.0
# 1393212  10208623  2016-01-11         t   87.0
# 1393213  10208623  2016-01-12         t   87.0
#
# [934542 rows x 4 columns]

# %%
seattle_prices.shape
# Out:
# (934542, 4)

# %%
boston_prices['price'] = boston_prices['price'].apply(lambda x : float(x.replace('$', '').replace(',', '')))
seattle_prices['price'] = seattle_prices['price'].apply(lambda x : float(x.replace('$', '').replace(',', '')))

# %%
boston_prices['price'].describe()
# Out:
# count    643037.000000
# mean        198.438909
# std         180.142913
# min          11.000000
# 25%          85.000000
# 50%         150.000000
# 75%         255.000000
# max        7163.000000
# Name: price, dtype: float64

# %%
seattle_prices['price'].describe()
# Out:
# count    934542.000000
# mean        137.944859
# std         105.062870
# min          10.000000
# 25%          75.000000
# 50%         109.000000
# 75%         160.000000
# max        1650.000000
# Name: price, dtype: float64

# %% [markdown]
# ## Two distribution t-test with different variance assumption

# %% [markdown]
# $$H_0 : \bar{X_1}\ =\ \bar{X_2}  \\ H_1 : \bar{X_1}\ !=\ \bar{X_2}$$

# %% [markdown]
# $$t = \frac{\bar{X_1} - \bar{X_2}}{s}\enspace$$  satisfies t-distribution where
# $$\enspace s = \sqrt{\frac{s_1^2}{n_1} + \frac{s_2^2}{n_2}}$$

# %% [markdown]
# Degree of freedom is equal to
# $$
# DF = \frac{(VAR_1 + VAR_2)^2}{\frac{VAR_1^2}{n_1 - 1} + \frac{VAR_2^2}{n_2 - 1}}
# $$

# %% [markdown]
# After testing, we find that the p-value is smaller than 0.001, which means that we should reject $H_0$ with a high confidence. And the average renting price between Boston and Seattle is very different.

# %%
s_2 = np.sqrt(seattle_prices['price'].std()**2 / seattle_prices['price'].shape[0] + \
              boston_prices['price'].std()**2 / boston_prices['price'].shape[0])

t = (seattle_prices['price'].mean() - boston_prices['price'].mean()) / s_2

# %%
t
# Out:
# -242.40846787381446

# %%
seattle_prices['price'].var()
# Out:
# 11038.206657946257

# %%
DF = (seattle_prices['price'].var() + boston_prices['price'].var())**2 / \
     (seattle_prices['price'].var()**2 / (seattle_prices['price'].shape[0] - 1) + \
      boston_prices['price'].var()**2 / (boston_prices['price'].shape[0] - 1))
DF
# Out:
# 1069725.0833099699

# %% [markdown]
# According to the t-test table, we find that the mean value for prices in Boston and Seattle is different. With p-value < 0.001

# %% [markdown]
# ## Price value histogram for Boston and Seattle cities

# %%
plt.hist(list(boston_prices[boston_prices['price'] < 5 * np.median(boston_prices['price'])]['price']), bins = 50)
#plt.hist(list(boston_prices[boston_prices['price'] < np.mean(boston_prices['price']) + \
#                                                     5 * np.std(boston_prices['price'])]['price']), bins = 50)
plt.show()

# %%
plt.hist(list(seattle_prices[seattle_prices['price'] < 5 * np.median(seattle_prices['price'])]['price']), bins = 50)
plt.show()

# %% [markdown]
# ## Make prediction towards price in two cities

# %%
boston_prices = boston_prices.rename(columns = {'listing_id' : 'id'})
seattle_prices = seattle_prices.rename(columns = {'listing_id' : 'id'})

# %%
boston_df = pd.merge(boston_listings, boston_prices, on = 'id')
seattle_df = pd.merge(seattle_listings, seattle_prices, on = 'id')

# %%
boston_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price_x', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month', 'date', 'available', 'price_y'],
#       dtype='object')

# %%
b_columns = [col for col in boston_df.columns if boston_df[col].dtype == 'float64' or boston_df[col].dtype == 'int64']
s_columns = [col for col in seattle_df.columns if seattle_df[col].dtype == 'float64' or seattle_df[col].dtype == 'int64']

# %%
boston_numeric = boston_df[b_columns]
seattle_numeric = seattle_df[s_columns]

# %% [markdown]
# ### Drop features with all null value

# %%
seattle_numeric.columns
# Out:
# Index(['id', 'scrape_id', 'host_id', 'host_listings_count',
#        'host_total_listings_count', 'latitude', 'longitude', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'square_feet', 'guests_included',
#        'minimum_nights', 'maximum_nights', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'calculated_host_listings_count',
#        'reviews_per_month', 'price_y'],
#       dtype='object')

# %%
boston_numeric.columns
# Out:
# Index(['id', 'scrape_id', 'host_id', 'host_listings_count',
#        'host_total_listings_count', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'square_feet', 'guests_included', 'minimum_nights', 'maximum_nights',
#        'has_availability', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'jurisdiction_names',
#        'calculated_host_listings_count', 'reviews_per_month', 'price_y'],
#       dtype='object')

# %%
boston_numeric = boston_numeric.drop(columns = boston_numeric.columns[boston_numeric.isnull().all()])
seattle_numeric = seattle_numeric.drop(columns = seattle_numeric.columns[seattle_numeric.isnull().all()])

# %%
boston_numeric.columns[boston_numeric.isnull().any()]
# Out:
# Index(['bathrooms', 'bedrooms', 'beds', 'square_feet', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'reviews_per_month'],
#       dtype='object')

# %%
boston_numeric[boston_numeric['bathrooms'].isnull()]
# Out:
#              id       scrape_id   host_id  host_listings_count  \
# 22141    777903  20160906204935   4102281                    1
# 22142    777903  20160906204935   4102281                    1
# 22143    777903  20160906204935   4102281                    1
# 22144    777903  20160906204935   4102281                    1
# 22145    777903  20160906204935   4102281                    1
# 22146    777903  20160906204935   4102281                    1
# 22147    777903  20160906204935   4102281                    1
# 22148    777903  20160906204935   4102281                    1
# 22149    777903  20160906204935   4102281                    1
# 22150    777903  20160906204935   4102281                    1
# 22151    777903  20160906204935   4102281                    1
# 22152    777903  20160906204935   4102281                    1
# 22153    777903  20160906204935   4102281                    1
# 22154    777903  20160906204935   4102281                    1
# 22155    777903  20160906204935   4102281                    1
# 22156    777903  20160906204935   4102281                    1
# 22157    777903  20160906204935   4102281                    1
# 22158    777903  20160906204935   4102281                    1
# 22159    777903  20160906204935   4102281                    1
# 22160    777903  20160906204935   4102281                    1
# 22161    777903  20160906204935   4102281                    1
# 22162    777903  20160906204935   4102281                    1
# 22163    777903  20160906204935   4102281                    1
# 22164    777903  20160906204935   4102281                    1
# 22165    777903  20160906204935   4102281                    1
# 22166    777903  20160906204935   4102281                    1
# 22167    777903  20160906204935   4102281                    1
# 22168    777903  20160906204935   4102281                    1
# 22169    777903  20160906204935   4102281                    1
# 22170    777903  20160906204935   4102281                    1
# ...         ...             ...       ...                  ...
# 502977  9239190  20160906204935  48020499                    1
# 502978  9239190  20160906204935  48020499                    1
# 502979  9239190  20160906204935  48020499                    1
# 502980  9239190  20160906204935  48020499                    1
# 502981  9239190  20160906204935  48020499                    1
# 502982  9239190  20160906204935  48020499                    1
# 502983  9239190  20160906204935  48020499                    1
# 502984  9239190  20160906204935  48020499                    1
# 502985  9239190  20160906204935  48020499                    1
# 502986  9239190  20160906204935  48020499                    1
# 502987  9239190  20160906204935  48020499                    1
# 502988  9239190  20160906204935  48020499                    1
# 502989  9239190  20160906204935  48020499                    1
# 502990  9239190  20160906204935  48020499                    1
# 502991  9239190  20160906204935  48020499                    1
# 502992  9239190  20160906204935  48020499                    1
# 502993  9239190  20160906204935  48020499                    1
# 502994  9239190  20160906204935  48020499                    1
# 502995  9239190  20160906204935  48020499                    1
# 502996  9239190  20160906204935  48020499                    1
# 502997  9239190  20160906204935  48020499                    1
# 502998  9239190  20160906204935  48020499                    1
# 502999  9239190  20160906204935  48020499                    1
# 503000  9239190  20160906204935  48020499                    1
# 503001  9239190  20160906204935  48020499                    1
# 503002  9239190  20160906204935  48020499                    1
# 503003  9239190  20160906204935  48020499                    1
# 503004  9239190  20160906204935  48020499                    1
# 503005  9239190  20160906204935  48020499                    1
# 503006  9239190  20160906204935  48020499                    1
#
#         host_total_listings_count   latitude  longitude  accommodates  \
# 22141                           1  42.307574 -71.134630             2
# 22142                           1  42.307574 -71.134630             2
# 22143                           1  42.307574 -71.134630             2
# 22144                           1  42.307574 -71.134630             2
# 22145                           1  42.307574 -71.134630             2
# 22146                           1  42.307574 -71.134630             2
# 22147                           1  42.307574 -71.134630             2
# 22148                           1  42.307574 -71.134630             2
# 22149                           1  42.307574 -71.134630             2
# 22150                           1  42.307574 -71.134630             2
# 22151                           1  42.307574 -71.134630             2
# 22152                           1  42.307574 -71.134630             2
# 22153                           1  42.307574 -71.134630             2
# 22154                           1  42.307574 -71.134630             2
# 22155                           1  42.307574 -71.134630             2
# 22156                           1  42.307574 -71.134630             2
# 22157                           1  42.307574 -71.134630             2
# 22158                           1  42.307574 -71.134630             2
# 22159                           1  42.307574 -71.134630             2
# 22160                           1  42.307574 -71.134630             2
# 22161                           1  42.307574 -71.134630             2
# 22162                           1  42.307574 -71.134630             2
# 22163                           1  42.307574 -71.134630             2
# 22164                           1  42.307574 -71.134630             2
# 22165                           1  42.307574 -71.134630             2
# 22166                           1  42.307574 -71.134630             2
# 22167                           1  42.307574 -71.134630             2
# 22168                           1  42.307574 -71.134630             2
# 22169                           1  42.307574 -71.134630             2
# 22170                           1  42.307574 -71.134630             2
# ...                           ...        ...        ...           ...
# 502977                          1  42.290891 -71.060188             2
# 502978                          1  42.290891 -71.060188             2
# 502979                          1  42.290891 -71.060188             2
# 502980                          1  42.290891 -71.060188             2
# 502981                          1  42.290891 -71.060188             2
# 502982                          1  42.290891 -71.060188             2
# 502983                          1  42.290891 -71.060188             2
# 502984                          1  42.290891 -71.060188             2
# 502985                          1  42.290891 -71.060188             2
# 502986                          1  42.290891 -71.060188             2
# 502987                          1  42.290891 -71.060188             2
# 502988                          1  42.290891 -71.060188             2
# 502989                          1  42.290891 -71.060188             2
# 502990                          1  42.290891 -71.060188             2
# 502991                          1  42.290891 -71.060188             2
# 502992                          1  42.290891 -71.060188             2
# 502993                          1  42.290891 -71.060188             2
# 502994                          1  42.290891 -71.060188             2
# 502995                          1  42.290891 -71.060188             2
# 502996                          1  42.290891 -71.060188             2
# 502997                          1  42.290891 -71.060188             2
# 502998                          1  42.290891 -71.060188             2
# 502999                          1  42.290891 -71.060188             2
# 503000                          1  42.290891 -71.060188             2
# 503001                          1  42.290891 -71.060188             2
# 503002                          1  42.290891 -71.060188             2
# 503003                          1  42.290891 -71.060188             2
# 503004                          1  42.290891 -71.060188             2
# 503005                          1  42.290891 -71.060188             2
# 503006                          1  42.290891 -71.060188             2
#
#         bathrooms  bedrooms   ...     review_scores_rating  \
# 22141         NaN       1.0   ...                     94.0
# 22142         NaN       1.0   ...                     94.0
# 22143         NaN       1.0   ...                     94.0
# 22144         NaN       1.0   ...                     94.0
# 22145         NaN       1.0   ...                     94.0
# 22146         NaN       1.0   ...                     94.0
# 22147         NaN       1.0   ...                     94.0
# 22148         NaN       1.0   ...                     94.0
# 22149         NaN       1.0   ...                     94.0
# 22150         NaN       1.0   ...                     94.0
# 22151         NaN       1.0   ...                     94.0
# 22152         NaN       1.0   ...                     94.0
# 22153         NaN       1.0   ...                     94.0
# 22154         NaN       1.0   ...                     94.0
# 22155         NaN       1.0   ...                     94.0
# 22156         NaN       1.0   ...                     94.0
# 22157         NaN       1.0   ...                     94.0
# 22158         NaN       1.0   ...                     94.0
# 22159         NaN       1.0   ...                     94.0
# 22160         NaN       1.0   ...                     94.0
# 22161         NaN       1.0   ...                     94.0
# 22162         NaN       1.0   ...                     94.0
# 22163         NaN       1.0   ...                     94.0
# 22164         NaN       1.0   ...                     94.0
# 22165         NaN       1.0   ...                     94.0
# 22166         NaN       1.0   ...                     94.0
# 22167         NaN       1.0   ...                     94.0
# 22168         NaN       1.0   ...                     94.0
# 22169         NaN       1.0   ...                     94.0
# 22170         NaN       1.0   ...                     94.0
# ...           ...       ...   ...                      ...
# 502977        NaN       1.0   ...                     87.0
# 502978        NaN       1.0   ...                     87.0
# 502979        NaN       1.0   ...                     87.0
# 502980        NaN       1.0   ...                     87.0
# 502981        NaN       1.0   ...                     87.0
# 502982        NaN       1.0   ...                     87.0
# 502983        NaN       1.0   ...                     87.0
# 502984        NaN       1.0   ...                     87.0
# 502985        NaN       1.0   ...                     87.0
# 502986        NaN       1.0   ...                     87.0
# 502987        NaN       1.0   ...                     87.0
# 502988        NaN       1.0   ...                     87.0
# 502989        NaN       1.0   ...                     87.0
# 502990        NaN       1.0   ...                     87.0
# 502991        NaN       1.0   ...                     87.0
# 502992        NaN       1.0   ...                     87.0
# 502993        NaN       1.0   ...                     87.0
# 502994        NaN       1.0   ...                     87.0
# 502995        NaN       1.0   ...                     87.0
# 502996        NaN       1.0   ...                     87.0
# 502997        NaN       1.0   ...                     87.0
# 502998        NaN       1.0   ...                     87.0
# 502999        NaN       1.0   ...                     87.0
# 503000        NaN       1.0   ...                     87.0
# 503001        NaN       1.0   ...                     87.0
# 503002        NaN       1.0   ...                     87.0
# 503003        NaN       1.0   ...                     87.0
# 503004        NaN       1.0   ...                     87.0
# 503005        NaN       1.0   ...                     87.0
# 503006        NaN       1.0   ...                     87.0
#
#         review_scores_accuracy  review_scores_cleanliness  \
# 22141                     10.0                        9.0
# 22142                     10.0                        9.0
# 22143                     10.0                        9.0
# 22144                     10.0                        9.0
# 22145                     10.0                        9.0
# 22146                     10.0                        9.0
# 22147                     10.0                        9.0
# 22148                     10.0                        9.0
# 22149                     10.0                        9.0
# 22150                     10.0                        9.0
# 22151                     10.0                        9.0
# 22152                     10.0                        9.0
# 22153                     10.0                        9.0
# 22154                     10.0                        9.0
# 22155                     10.0                        9.0
# 22156                     10.0                        9.0
# 22157                     10.0                        9.0
# 22158                     10.0                        9.0
# 22159                     10.0                        9.0
# 22160                     10.0                        9.0
# 22161                     10.0                        9.0
# 22162                     10.0                        9.0
# 22163                     10.0                        9.0
# 22164                     10.0                        9.0
# 22165                     10.0                        9.0
# 22166                     10.0                        9.0
# 22167                     10.0                        9.0
# 22168                     10.0                        9.0
# 22169                     10.0                        9.0
# 22170                     10.0                        9.0
# ...                        ...                        ...
# 502977                     9.0                        9.0
# 502978                     9.0                        9.0
# 502979                     9.0                        9.0
# 502980                     9.0                        9.0
# 502981                     9.0                        9.0
# 502982                     9.0                        9.0
# 502983                     9.0                        9.0
# 502984                     9.0                        9.0
# 502985                     9.0                        9.0
# 502986                     9.0                        9.0
# 502987                     9.0                        9.0
# 502988                     9.0                        9.0
# 502989                     9.0                        9.0
# 502990                     9.0                        9.0
# 502991                     9.0                        9.0
# 502992                     9.0                        9.0
# 502993                     9.0                        9.0
# 502994                     9.0                        9.0
# 502995                     9.0                        9.0
# 502996                     9.0                        9.0
# 502997                     9.0                        9.0
# 502998                     9.0                        9.0
# 502999                     9.0                        9.0
# 503000                     9.0                        9.0
# 503001                     9.0                        9.0
# 503002                     9.0                        9.0
# 503003                     9.0                        9.0
# 503004                     9.0                        9.0
# 503005                     9.0                        9.0
# 503006                     9.0                        9.0
#
#         review_scores_checkin  review_scores_communication  \
# 22141                    10.0                         10.0
# 22142                    10.0                         10.0
# 22143                    10.0                         10.0
# 22144                    10.0                         10.0
# 22145                    10.0                         10.0
# 22146                    10.0                         10.0
# 22147                    10.0                         10.0
# 22148                    10.0                         10.0
# 22149                    10.0                         10.0
# 22150                    10.0                         10.0
# 22151                    10.0                         10.0
# 22152                    10.0                         10.0
# 22153                    10.0                         10.0
# 22154                    10.0                         10.0
# 22155                    10.0                         10.0
# 22156                    10.0                         10.0
# 22157                    10.0                         10.0
# 22158                    10.0                         10.0
# 22159                    10.0                         10.0
# 22160                    10.0                         10.0
# 22161                    10.0                         10.0
# 22162                    10.0                         10.0
# 22163                    10.0                         10.0
# 22164                    10.0                         10.0
# 22165                    10.0                         10.0
# 22166                    10.0                         10.0
# 22167                    10.0                         10.0
# 22168                    10.0                         10.0
# 22169                    10.0                         10.0
# 22170                    10.0                         10.0
# ...                       ...                          ...
# 502977                    8.0                          9.0
# 502978                    8.0                          9.0
# 502979                    8.0                          9.0
# 502980                    8.0                          9.0
# 502981                    8.0                          9.0
# 502982                    8.0                          9.0
# 502983                    8.0                          9.0
# 502984                    8.0                          9.0
# 502985                    8.0                          9.0
# 502986                    8.0                          9.0
# 502987                    8.0                          9.0
# 502988                    8.0                          9.0
# 502989                    8.0                          9.0
# 502990                    8.0                          9.0
# 502991                    8.0                          9.0
# 502992                    8.0                          9.0
# 502993                    8.0                          9.0
# 502994                    8.0                          9.0
# 502995                    8.0                          9.0
# 502996                    8.0                          9.0
# 502997                    8.0                          9.0
# 502998                    8.0                          9.0
# 502999                    8.0                          9.0
# 503000                    8.0                          9.0
# 503001                    8.0                          9.0
# 503002                    8.0                          9.0
# 503003                    8.0                          9.0
# 503004                    8.0                          9.0
# 503005                    8.0                          9.0
# 503006                    8.0                          9.0
#
#         review_scores_location  review_scores_value  \
# 22141                     10.0                 10.0
# 22142                     10.0                 10.0
# 22143                     10.0                 10.0
# 22144                     10.0                 10.0
# 22145                     10.0                 10.0
# 22146                     10.0                 10.0
# 22147                     10.0                 10.0
# 22148                     10.0                 10.0
# 22149                     10.0                 10.0
# 22150                     10.0                 10.0
# 22151                     10.0                 10.0
# 22152                     10.0                 10.0
# 22153                     10.0                 10.0
# 22154                     10.0                 10.0
# 22155                     10.0                 10.0
# 22156                     10.0                 10.0
# 22157                     10.0                 10.0
# 22158                     10.0                 10.0
# 22159                     10.0                 10.0
# 22160                     10.0                 10.0
# 22161                     10.0                 10.0
# 22162                     10.0                 10.0
# 22163                     10.0                 10.0
# 22164                     10.0                 10.0
# 22165                     10.0                 10.0
# 22166                     10.0                 10.0
# 22167                     10.0                 10.0
# 22168                     10.0                 10.0
# 22169                     10.0                 10.0
# 22170                     10.0                 10.0
# ...                        ...                  ...
# 502977                     9.0                  9.0
# 502978                     9.0                  9.0
# 502979                     9.0                  9.0
# 502980                     9.0                  9.0
# 502981                     9.0                  9.0
# 502982                     9.0                  9.0
# 502983                     9.0                  9.0
# 502984                     9.0                  9.0
# 502985                     9.0                  9.0
# 502986                     9.0                  9.0
# 502987                     9.0                  9.0
# 502988                     9.0                  9.0
# 502989                     9.0                  9.0
# 502990                     9.0                  9.0
# 502991                     9.0                  9.0
# 502992                     9.0                  9.0
# 502993                     9.0                  9.0
# 502994                     9.0                  9.0
# 502995                     9.0                  9.0
# 502996                     9.0                  9.0
# 502997                     9.0                  9.0
# 502998                     9.0                  9.0
# 502999                     9.0                  9.0
# 503000                     9.0                  9.0
# 503001                     9.0                  9.0
# 503002                     9.0                  9.0
# 503003                     9.0                  9.0
# 503004                     9.0                  9.0
# 503005                     9.0                  9.0
# 503006                     9.0                  9.0
#
#         calculated_host_listings_count  reviews_per_month  price_y
# 22141                                1               0.43     85.0
# 22142                                1               0.43     85.0
# 22143                                1               0.43     85.0
# 22144                                1               0.43     85.0
# 22145                                1               0.43     85.0
# 22146                                1               0.43     85.0
# 22147                                1               0.43     85.0
# 22148                                1               0.43     85.0
# 22149                                1               0.43     85.0
# 22150                                1               0.43     85.0
# 22151                                1               0.43     85.0
# 22152                                1               0.43     85.0
# 22153                                1               0.43     85.0
# 22154                                1               0.43     85.0
# 22155                                1               0.43     85.0
# 22156                                1               0.43     85.0
# 22157                                1               0.43     85.0
# 22158                                1               0.43     85.0
# 22159                                1               0.43     85.0
# 22160                                1               0.43     85.0
# 22161                                1               0.43     85.0
# 22162                                1               0.43     85.0
# 22163                                1               0.43     85.0
# 22164                                1               0.43     85.0
# 22165                                1               0.43     85.0
# 22166                                1               0.43     85.0
# 22167                                1               0.43     85.0
# 22168                                1               0.43     85.0
# 22169                                1               0.43     85.0
# 22170                                1               0.43     85.0
# ...                                ...                ...      ...
# 502977                               1               1.20     57.0
# 502978                               1               1.20     57.0
# 502979                               1               1.20     57.0
# 502980                               1               1.20     53.0
# 502981                               1               1.20     53.0
# 502982                               1               1.20     57.0
# 502983                               1               1.20     57.0
# 502984                               1               1.20     57.0
# 502985                               1               1.20     57.0
# 502986                               1               1.20     57.0
# 502987                               1               1.20     53.0
# 502988                               1               1.20     53.0
# 502989                               1               1.20     57.0
# 502990                               1               1.20     57.0
# 502991                               1               1.20     57.0
# 502992                               1               1.20     57.0
# 502993                               1               1.20     57.0
# 502994                               1               1.20     53.0
# 502995                               1               1.20     53.0
# 502996                               1               1.20     57.0
# 502997                               1               1.20     57.0
# 502998                               1               1.20     57.0
# 502999                               1               1.20     57.0
# 503000                               1               1.20     57.0
# 503001                               1               1.20     53.0
# 503002                               1               1.20     53.0
# 503003                               1               1.20     57.0
# 503004                               1               1.20     57.0
# 503005                               1               1.20     57.0
# 503006                               1               1.20     53.0
#
# [4454 rows x 30 columns]

# %% [markdown]
# ### fill na with median of columns

# %%
fill_median = lambda col : col.fillna(col.median())
boston_numeric = boston_numeric.apply(fill_median, axis = 0)
seattle_numeric = seattle_numeric.apply(fill_median, axis = 0)

# %%
boston_numeric.columns
# Out:
# Index(['id', 'scrape_id', 'host_id', 'host_listings_count',
#        'host_total_listings_count', 'latitude', 'longitude', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'square_feet', 'guests_included',
#        'minimum_nights', 'maximum_nights', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'calculated_host_listings_count',
#        'reviews_per_month', 'price_y'],
#       dtype='object')

# %%
seattle_numeric.columns
# Out:
# Index(['id', 'scrape_id', 'host_id', 'host_listings_count',
#        'host_total_listings_count', 'latitude', 'longitude', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'square_feet', 'guests_included',
#        'minimum_nights', 'maximum_nights', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'calculated_host_listings_count',
#        'reviews_per_month', 'price_y'],
#       dtype='object')

# %% [markdown]
# ### Filter useless features

# %%
boston_numeric = boston_numeric.drop(columns=['scrape_id', 'host_id'])
seattle_numeric = seattle_numeric.drop(columns=['scrape_id', 'host_id'])

# %%
train_id, test_id = train_test_id(boston_numeric['id'].unique())

# %% [markdown]
# # price prediction with xgboost

# %%
def train_test_id(id_lst, test_portion = 0.25):
    """
        Randomly split training and test id.
        Input: 
            id_lst is the list of all ids
        return:
            train_id_list, test_id_list
    """
    id_lst = list(id_lst)
    cnt = 0
    size = len(id_lst)
    test_lst = []
    while True:
        pos = int(np.floor(np.random.rand() * len(id_lst)))
        test_lst.append(id_lst.pop(pos))
        cnt += 1
        if len(test_lst) >= test_portion * size:
            break
    return id_lst, test_lst

# %%
X_boston, y_boston = boston_numeric.loc[:,boston_numeric.columns != 'price_y'], boston_numeric['price_y']
X_seattle, y_seattle = seattle_numeric.loc[:,seattle_numeric.columns != 'price_y'], seattle_numeric['price_y']

# %%
def search_params(params, estimator, X, y, cv = 5):
    clf = GridSearchCV(estimator, params, cv = cv, scoring = 'neg_mean_squared_error', verbose = 2)
    clf.fit(X, y)
    return clf.best_params_

def cal_rmse(y_pred, y_true):
    return np.sqrt(np.sum((y_pred - y_true)**2 / len(y_pred)))

# %% [markdown]
# ## Boston price prediction:

# %%
X_boston.head()
# Out:
#    host_listings_count  host_total_listings_count   latitude  longitude  \
# 0                    1                          1  42.286241 -71.134374
# 1                    1                          1  42.286241 -71.134374
# 2                    1                          1  42.286241 -71.134374
# 3                    1                          1  42.286241 -71.134374
# 4                    1                          1  42.286241 -71.134374
#
#    accommodates  bathrooms  bedrooms  beds  square_feet  guests_included  \
# 0             2        1.0       1.0   1.0        800.0                0
# 1             2        1.0       1.0   1.0        800.0                0
# 2             2        1.0       1.0   1.0        800.0                0
# 3             2        1.0       1.0   1.0        800.0                0
# 4             2        1.0       1.0   1.0        800.0                0
#
#          ...          number_of_reviews  review_scores_rating  \
# 0        ...                         36                  94.0
# 1        ...                         36                  94.0
# 2        ...                         36                  94.0
# 3        ...                         36                  94.0
# 4        ...                         36                  94.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                        9.0                   10.0
# 1                    10.0                        9.0                   10.0
# 2                    10.0                        9.0                   10.0
# 3                    10.0                        9.0                   10.0
# 4                    10.0                        9.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     9.0                  9.0
# 1                         10.0                     9.0                  9.0
# 2                         10.0                     9.0                  9.0
# 3                         10.0                     9.0                  9.0
# 4                         10.0                     9.0                  9.0
#
#    calculated_host_listings_count  reviews_per_month
# 0                               1                1.3
# 1                               1                1.3
# 2                               1                1.3
# 3                               1                1.3
# 4                               1                1.3
#
# [5 rows x 26 columns]

# %%
boston_numeric.head()
# Out:
#         id  host_listings_count  host_total_listings_count   latitude  \
# 0  3075044                    1                          1  42.286241
# 1  3075044                    1                          1  42.286241
# 2  3075044                    1                          1  42.286241
# 3  3075044                    1                          1  42.286241
# 4  3075044                    1                          1  42.286241
#
#    longitude  accommodates  bathrooms  bedrooms  beds  square_feet   ...     \
# 0 -71.134374             2        1.0       1.0   1.0        800.0   ...
# 1 -71.134374             2        1.0       1.0   1.0        800.0   ...
# 2 -71.134374             2        1.0       1.0   1.0        800.0   ...
# 3 -71.134374             2        1.0       1.0   1.0        800.0   ...
# 4 -71.134374             2        1.0       1.0   1.0        800.0   ...
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  94.0                    10.0                        9.0
# 1                  94.0                    10.0                        9.0
# 2                  94.0                    10.0                        9.0
# 3                  94.0                    10.0                        9.0
# 4                  94.0                    10.0                        9.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                     9.0
# 1                   10.0                         10.0                     9.0
# 2                   10.0                         10.0                     9.0
# 3                   10.0                         10.0                     9.0
# 4                   10.0                         10.0                     9.0
#
#    review_scores_value  calculated_host_listings_count  reviews_per_month  \
# 0                  9.0                               1                1.3
# 1                  9.0                               1                1.3
# 2                  9.0                               1                1.3
# 3                  9.0                               1                1.3
# 4                  9.0                               1                1.3
#
#    price_y
# 0     65.0
# 1     65.0
# 2     65.0
# 3     75.0
# 4     75.0
#
# [5 rows x 28 columns]

# %%
train_id, test_id = train_test_id(boston_numeric['id'].unique())
train_entries = list(tqdm(map(lambda x : x in train_id, boston_numeric['id'])))
test_entries = list(tqdm(map(lambda x : x in test_id, boston_numeric['id'])))

X_train, X_test, y_train, y_test = X_boston[train_entries], X_boston[test_entries], \
                                   y_boston[train_entries], y_boston[test_entries]
# Out:
# 643037it [01:43, 6239.07it/s]
# 643037it [00:48, 13302.79it/s]

# %%
X_train.shape[0] / X_test.shape[0]
# Out:
# 3.12790637959147

# %%
X_test.shape
# Out:
# (155778, 26)

# %%
params = {'max_depth' : [3, 5],
          'learning_rate' : [0.05, 0.1]
          'n_estimators' : [100]}

xgb = XGBRegressor(booster='gbtree', n_jobs=2)
boston_opt_params = search_params(params, xgb, X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] learning_rate=0.05, n_estimators=100, max_depth=3 ...............
# [CV]  learning_rate=0.05, n_estimators=100, max_depth=3, total=  23.1s
# [CV] learning_rate=0.05, n_estimators=100, max_depth=3 ...............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   23.8s remaining:    0.0s
# [CV]  learning_rate=0.05, n_estimators=100, max_depth=3, total=  23.8s
# [CV] learning_rate=0.05, n_estimators=100, max_depth=3 ...............
# [CV]  learning_rate=0.05, n_estimators=100, max_depth=3, total=  26.1s
# [CV] learning_rate=0.05, n_estimators=100, max_depth=3 ...............
# [CV]  learning_rate=0.05, n_estimators=100, max_depth=3, total=  24.2s
# [CV] learning_rate=0.05, n_estimators=100, max_depth=3 ...............
# [CV]  learning_rate=0.05, n_estimators=100, max_depth=3, total=  22.6s
# [CV] learning_rate=0.05, n_estimators=100, max_depth=5 ...............
# [CV]  learning_rate=0.05, n_estimators=100, max_depth=5, total=  38.7s
# [CV] learning_rate=0.05, n_estimators=100, max_depth=5 ...............
# [CV]  learning_rate=0.05, n_estimators=100, max_depth=5, total=  38.5s
# [CV] learning_rate=0.05, n_estimators=100, max_depth=5 ...............
# [CV]  learning_rate=0.05, n_estimators=100, max_depth=5, total=  38.0s
# [CV] learning_rate=0.05, n_estimators=100, max_depth=5 ...............
# [CV]  learning_rate=0.05, n_estimators=100, max_depth=5, total=  37.9s
# [CV] learning_rate=0.05, n_estimators=100, max_depth=5 ...............
# [CV]  learning_rate=0.05, n_estimators=100, max_depth=5, total=  38.0s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=3 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=3, total=  23.3s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=3 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=3, total=  22.5s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=3 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=3, total=  23.1s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=3 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=3, total=  23.4s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=3 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=3, total=  23.0s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=5, total=  38.2s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=5, total=  38.1s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=5, total=  39.1s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=5, total=  37.8s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=5, total=  38.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed: 10.6min finished

# %%
xgb_boston = XGBRegressor(booster='gbtree', **boston_opt_params)
xgb_boston.fit(X_train, y_train, eval_metric = 'rmse')
y_pred = xgb_boston.predict(X_test)

# %%
print(cal_rmse(y_pred, y_test))
# Out:
# 66.35793008208223

# %%
def visualize_pred(y_pred, y_test, city = 'Boston'):
    fig, ax = plt.subplots(figsize=(10,8))
    ax.set(xlabel='Samples', ylabel='prices',
           title='Predicted and true price comparison for Airbnb in ' + city +' area(100 samples)')
    ax.plot(range(len(y_pred[:100])),y_pred[:100], color = 'blue')
    ax.plot(range(len(y_test[:100])),y_test[:100], color = 'red')
    ax.legend(('predicted price', 'true price'),
               loc='upper right')
    plt.show()

# %%
visualize_pred(y_pred, y_test)

# %% [markdown]
# ## Seattle price prediction:

# %%
X_seattle, y_seattle = seattle_numeric.loc[:,seattle_numeric.columns != 'price_y'], seattle_numeric['price_y']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_seattle, y_seattle)
params = {'max_depth' : [5],
          'learning_rate' : [0.1],
          'n_estimators' : [100, 200]}

xgb = XGBRegressor(booster='gbtree', n_jobs=2)
seattle_opt_params = search_params(params, xgb, X_train, y_train)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] learning_rate=0.1, n_estimators=100, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=5, total=  54.0s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=5 ................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   55.7s remaining:    0.0s
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=5, total=  54.5s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=5, total=  55.3s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=5, total=  52.3s
# [CV] learning_rate=0.1, n_estimators=100, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=100, max_depth=5, total=  52.2s
# [CV] learning_rate=0.1, n_estimators=200, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=200, max_depth=5, total= 1.8min
# [CV] learning_rate=0.1, n_estimators=200, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=200, max_depth=5, total= 1.7min
# [CV] learning_rate=0.1, n_estimators=200, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=200, max_depth=5, total= 1.7min
# [CV] learning_rate=0.1, n_estimators=200, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=200, max_depth=5, total= 1.7min
# [CV] learning_rate=0.1, n_estimators=200, max_depth=5 ................
# [CV] . learning_rate=0.1, n_estimators=200, max_depth=5, total= 1.7min
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 13.4min finished

# %%
xgb_seattle = XGBRegressor(booster='gbtree', **seattle_opt_params)
xgb_seattle.fit(X_train, y_train, eval_metric = 'rmse')
y_pred_seattle = xgb_seattle.predict(X_test)
print(cal_rmse(y_pred_seattle, y_test))
# Out:
# 36.855132499376325

# %%
seattle_opt_params
# Out:
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}

# %%
visualize_pred(y_pred_seattle, y_test, 'Seattle')

# %% [markdown]
# # Top important features for price prediction

# %%
def visualize_feature(features, feat_importance, city = 'Boston'):
    fig, ax = plt.subplots(figsize=(10,8))
    ax.set(xlabel='feature name', ylabel='feature importance',
           title='feature importance level for ' + city + ' city')
    ax.bar(features, feat_importance)
    plt.xticks(features, rotation='vertical')
    plt.show()

# %% [markdown]
# ### Boston city

# %%
plot_importance(xgb_boston, height=0.5, show_values=False, xlabel='Feature importance level', \
                title='Feature importance graph for Boston city')
plt.show()

# %% [markdown]
# ### Seattle city

# %%
plot_importance(xgb_seattle, height=0.5, show_values=False, xlabel='Feature importance level', \
                title='Feature importance graph for Seattle city')
plt.show()
